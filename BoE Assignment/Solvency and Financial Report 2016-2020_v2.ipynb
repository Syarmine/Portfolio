# %% [markdown]
# ## Solvency and Financial Report of Insurance Firms for the Bank of England
# (Analysed by: Syarmine Shah)
#
# ### **Background:**
#
# This report is part of technical assignment for Analyst - Systems, Change and Banking Data team (PRA Strategy, Risk & Operations) (009533) role at the Bank of Egnland.
#
# This report contains the results of data analysis assignment of insurance firms across the United Kingdom under the Bank of England and Prudential Regulation Authority (PRA).
#
# In total, there are 325 firms in the dataset with 8 business profile metrics and 9 underwriting metrics, ranging from 2016 and 2020 period. The following are the metrics in the dataset:
#
# |General|Underwriting|
# |---|---|
# |Gross_claims_incurred_(£m)|	NWP_(£m)|
# |Gross_BEL_(inc._TPs_as_whole,_pre-TMTP)_(£m)|	SCR_(£m)|
# |Net_BEL_(inc._TPs_as_a_whole,_pre-TMTP)_(£m)|	EoF_for_SCR_(£m)|
# |Pure_net_claims_ratio|	SCR_coverage_ratio|
# |Net_expense_ratio|	GWP_(£m)|
# |Net_combined_ratio|	Total_assets_(£m)|
# |Pure_gross_claims_ratio|	Total_liabilities_(£m)|
# |Gross_expense_ratio|	Excess_of_assets_over_liabilities_(£m)_[=_equity]|
# |Gross_combined_ratio|	|
#
# I would like Bank of England for this opportunity be a part of this assessment and analysing firm-level insurance dataset. The report covers the requirements for technical assessment assigned by the Bank of England.
#
# This report sets out my findings on firm's profile and provides thematic observations that support improvements in supervisory resource allocation management. PRA Supervision teams will use individual firm responses to inform their supervisory strategy, which may result in follow-up discussions and actions.

# %% [markdown]
# ## 1. Firms Analysis
#
# To analyse the firm size, the following metrics are selected
# * Total Assets(TA)
# * Gross Written Premium (GWP)
# * Net Written Premium (NWP)
#
#
# From 2016 to 2020 period, the following table summarise the sum of each of the metrics
#
# |Year |TA(£b)|GWP(£b)|NWP(£m)|
# |---|---|---|---|
# | 2016|2,302.48|273.69|207.22|
# | 2017|2,355.99⬆️(2.23%)|295.67 (⬆️8.03%)|259.87(⬆️25.41%)|
# | 2018|2,252.26🔻(-4.40%)| 340.19(⬆️15.06%)| 274.31(⬆️5.56%)|
# | 2019| 2,473.09⬆️(9.80%)|316.05(🔻-7.10%)| 254.27(🔻-7.31%)|
# | 2020| 2,458.37🔻(-0.59%) | 269.89(🔻-14.61%| 213.96(🔻-15.85%)|
#
# * From 2016 to 2020, the following is a trend line across 5 years period by TA, GWP and NWP.
#  ![image-4.png](attachment:image-4.png)
#
# * In 2020, at firm level, the following shows the top 10 firms based on TA, GWP, and NWP.
# ![image.png](attachment:image.png)
#
# * The firms dataset are further analysed using concentration and distributions measures (CDMs) as recommended by [International Monetary Fund 2019: Financial Soundness Indicator Compilation Guide](https://www.imf.org/en/Data/Statistics/FSI-guide)
# ![tnwptgwpta.png](attachment:tnwptgwpta.png)
#
# ### Key Insights
#
# * **Total Asset**: In 2020, the total assets across all firms amounted to over £2,458.37 billion, marking a slight decrease of 0.59% from the previous year. Among the 325 firms analyzed, Firm 210 stood out with the largest assets, amounting to over £332.88 billion, which constituted a significant market share of 13.54%. Firm 311 was a close second, holding 13.08% of the market share. Other notable firms included Firm 105, Firm 34, and Firm 10, which respectively held market shares of 7.75%, 7.53%, and 5.78%.
#
# 2. **Gross Written Premium (GWP)**: In 2020, the Gross Written Premium (GWP) across all firms totalled over £269.89 billion, marking a decrease of 14.61% from the previous year. Firm 210 led the market with the highest GWP, with over £40,135.69 billion and capturing a substantial market share of 14.87%. Firm 4 followed closely with a 12.94% share, reflecting a growth of 1.51% from 2019. These two firms, Firm 210 and Firm 4, dominated the market. Trailing behind them were Firm 34 and Firm 311, which held market shares of 7.60% and 7.11% respectively.
#
# 3. **Net Written Premium (NWP)**: Firm 210 and Firm 4 also significantly influenced the market in terms of Net Written Premium (NWP), with respective shares of £40,135.69 (18.76%) and £24,996.02 (11.68%). Firm 311 held a notable position in the market with a share of 5.06%. while all other firms in the market held less than 5% of the NWP.
#
# 4. The following shows the NWP/GWP ratio across 10 insurance firms.
#
# ![tnwp_tgwp_ratio_png-2.png](attachment:tnwp_tgwp_ratio_png-2.png)

# %% [markdown]
# ## 2. Business Trends

# %% [markdown]
# The following shows top 10 firm year-on-year across 2016 to 2020.
#
# **2.1 Gross claims incurred**
# ![image.png](attachment:image.png)
#
#
#
# **2.2 Pure Gross Claims Ratio**
#  * Across 5 year period, there are notable variation of the pure gross claim ratio across the 325 firms, with 285 firms are within 0% to 62%, excluding outlier (see next section). Generally there pure gross claim ratio is below 100% across the 5 years, except year 2020, where the top 10 firms are above 100% ratio.
# ![image-2.png](attachment:image-2.png)
# * In 2020, Firm 144, Firm 29 and Firm 91 has pure gross claim ratio of over 130% with values of 137%, 134% and 130%, with increase in YoY of 75.8%, 401,486%, and 65.41% each respectively. Image below on the left hand side is the pure gross claim ratio values, and on the right side is the YoY over the previous year.
#
# ![tpgcr.PNG](attachment:tpgcr.PNG)
# ![tpgcryoy.PNG](attachment:tpgcryoy.PNG)
#
# **2.3 Net Combined Ratio**
#  * Across 5 year period, there are notable variation of the net combined ratio across the 325 firms, with 285 firms are within 0% to 97.9% in year 2020, excluding outlier (see next section). Generally there net combined ratio are below 100% across the 5 years, except year 2020, where the top 10 firms are above 100% ratio.
# ![image-3.png](attachment:image-3.png)
# * In 2020, Firm 97, Firm 21 and Firm 29, have a net combined ratio of 239%%, 230%% and 215% with a variation in YoY increment of 139%, 238% and 183% each respectively.Image below is the net combined ratio values.
# * ![tncri.PNG](attachment:tncri.PNG)
# * The following is the YoY of the net combined ratio as mentioned.
# * ![tncriyoy.PNG](attachment:tncriyoy.PNG)
#
#
# **2.4 Solvency Coverage Ratio**
#  * Across 5 year period, most of the firms are above 100% from 2016 to 2019 ranging from 159% to 167%. In 2020, there is notable spread of the solvency coverage ratio with 25% of the firms are in the range of 0% from the requirement, compared to 55% to 69% in 2016 to 2019. Outliers are discussed in the next section.
#
# ![image-4.png](attachment:image-4.png)
# * * In 2020, Firm 20, Firm 62 and Firm 13, have a solvency coverage ratio of 543%, 503% and 459%% with a variation in YoY increment of 42%, 49% and 16% each respectively.Image below is the solvency coverage ratios sorted by Year 2020.
# * ![tscrcr.PNG](attachment:tscrcr.PNG)
# * The following is the YoY of the solvency coverage ratio as mentioned.
# * ![tscrcryoy.PNG](attachment:tscrcryoy.PNG)

# %% [markdown]
# ## 3. Outliers
#
# The following methods are taken to identify outliers within this dataset
# - The use of concentration and distribution measures
# - Identification using boxplot
#
# **3.1 Pure Gross Claim Ratio**
# * The following boxplot are generated when the code is run for the first time. The boxplot can't be visualised as there is an extreme value in year 2019.
# ![image.png](attachment:image.png)
# * Using the describe method, there is notable extreme outliers within the dataset. The outliers is from the datapoint in 2019, where the maximum value of pure gross claim ratio is at 1,911,108 from Firm 188. There are 40 firms that are excluded and identified as outliers.
#
# * ![tpgcroutlier.PNG](attachment:tpgcroutlier.PNG)
#
# **3.2 Net Combined Ratio**
#
# * The following boxplot are generated when the code is run.
# ![image-2.png](attachment:image-2.png)
# * Using describe method, there is extereme data value in the dataset in year 2019, with a net combined ratio of 2,430,023. The firm identified is Firm 188.
# * ![tncrioutlier.PNG](attachment:tncrioutlier.PNG)
# * Additionally, when it is sort by 2020, Firm 228, Firm 166 and Firm 284 have a net combined ratio of over 9000, with values of 10,760%%, 9,891%, and 9,063% with increase in YoY of 75.8%, 401,486%, and 65.41% each respectively. Image below on the left hand side is the pure gross claim ratio values, and on the right side is the YoY over the previous year
#
# **3.3 Solvency Coverage Ratio**
#
# * The following boxplot are generated when the code is run showing extreme outliers in year 2017.
# ![image-3.png](attachment:image-3.png)
# * Using describe method, there is extereme data value in the dataset in year 2017, with a solvency coverage ratio 963,584,000.00. Upon sorting by year 2017, the firm identified is Firm 216. The solvency coverage ratio are followed closely by Firm 1, Firm 131, and Firm 127 with 481,792,000%, 481,792,000% and 182,412% each respectively.
# * ![image-4.png](attachment:image-4.png)
# * ![image-5.png](attachment:image-5.png)
# * The data for Firm 127 the following years from 2018 to 2020 shows a close average ranging from 166,394% to 194,753%.

# %% [markdown]
# # Annex
#
# The following section details out the Python script for this report:

# %%
# script made by Muhammad Syarmine Bin Mohd Shah
# Feels free to contact me at syarmineshah@yahoo.com for feedback
# import required libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as xl # import the dataset using pandas pd.read_excel with openpyxl package 
import plotly_express as px

# %% [markdown]
# ### Getting and structuring the data

# %%
# get data from github
url = "https://github.com/Syarmine/Portfolio/raw/main/BoE%20Assignment/Data%20for%20technical%20assessment.xlsx"
dict_df = pd.read_excel(url,
                header=0, #add indexing without including the dataset
                sheet_name=[0,1]) # get sheet 1 and sheet 2

df = dict_df.get(0) 
df_1 = dict_df.get(1)

# %%
# check the data shape
print(df.shape)
print(df_1.shape)

# check the Dataset 1 head
df.head()
# Out:
# (326, 41)
# (326, 46)
#   Unnamed: 0     NWP (£m)    NWP (£m) .1   NWP (£m) .2   NWP (£m) .3  \
# 0        NaN        2016YE        2017YE        2018YE        2019YE
# 1     Firm 1 -13779.815629             0             0             0
# 2     Firm 2     28.178059     26.865049     25.064438     23.226445
# 3     Firm 3             0     75.609681     70.578732     78.432782
# 4     Firm 4  22344.199923  23963.910709  25760.390158  25512.748836
#
#     NWP (£m) .4     SCR (£m)  SCR (£m).1  SCR (£m).2   SCR (£m).3  ...  \
# 0        2020YE       2016YE      2017YE      2018YE       2019YE  ...
# 1             0  1085.360139         0.0           0            0  ...
# 2     21.718558    10.190314   10.113572    9.495235     8.146471  ...
# 3      85.73583   322.955115  363.782327  362.290859   394.295982  ...
# 4  24996.021042   16573.6448  16332.7488   17103.616  17219.24608  ...
#
#   Total liabilities (£m) Total liabilities (£m).1 Total liabilities (£m).2  \
# ...

# %%
# check the Dataset 2 head
df_1.head()
# Out:
#   Unnamed: 0 Gross claims incurred (£m) Gross claims incurred (£m).1  \
# 0        NaN                     2016YE                       2017YE
# 1     Firm 1                          0                     0.046674
# 2     Firm 2                  39.241067                    35.948249
# 3     Firm 3                          0                            0
# 4     Firm 4                  17.125976                    75.535951
#
#   Gross claims incurred (£m).2 Gross claims incurred (£m).3  \
# 0                       2018YE                       2019YE
# 1                            0                            0
# 2                    29.002244                            0
# 3                            0                            0
# 4                   119.426995                    35.884204
#
#   Gross claims incurred (£m).4 Gross BEL (inc. TPs as whole, pre-TMTP) (£m)  \
# 0                       2020YE                                       2016YE
# ...

# %%
# check for missing values for Dataset 1
df.isnull().sum()
# Out:
# Unnamed: 0                                             1
# NWP (£m)                                               0
# NWP (£m) .1                                            0
# NWP (£m) .2                                            0
# NWP (£m) .3                                            0
# NWP (£m) .4                                            0
# SCR (£m)                                               0
# SCR (£m).1                                             0
# SCR (£m).2                                             0
# SCR (£m).3                                             0
# SCR (£m).4                                             0
# EoF for SCR (£m)                                       0
# EoF for SCR (£m).1                                     0
# EoF for SCR (£m).2                                     0
# EoF for SCR (£m).3                                     0
# EoF for SCR (£m).4                                     0
# ...

# %%
# check for missing values for Dataset 2
df_1.isnull().sum()
# Out:
# Unnamed: 0                                        1
# Gross claims incurred (£m)                        0
# Gross claims incurred (£m).1                      0
# Gross claims incurred (£m).2                      0
# Gross claims incurred (£m).3                      0
# Gross claims incurred (£m).4                      0
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m)      0
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).1    0
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).2    0
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).3    0
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).4    0
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m)      0
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).1    0
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).2    0
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).3    0
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).4    0
# Pure net claims ratio                             0
# Pure net claims ratio.1                           0
# ...

# %%
# check the data type for Dataset 1
df.dtypes
# Out:
# Unnamed: 0                                             object
# NWP (£m)                                               object
# NWP (£m) .1                                            object
# NWP (£m) .2                                            object
# NWP (£m) .3                                            object
# NWP (£m) .4                                            object
# SCR (£m)                                               object
# SCR (£m).1                                             object
# SCR (£m).2                                             object
# SCR (£m).3                                             object
# SCR (£m).4                                             object
# EoF for SCR (£m)                                       object
# EoF for SCR (£m).1                                     object
# EoF for SCR (£m).2                                     object
# EoF for SCR (£m).3                                     object
# ...

# %%
# check the data type for Dataset 2
df_1.dtypes
# Out:
# Unnamed: 0                                        object
# Gross claims incurred (£m)                        object
# Gross claims incurred (£m).1                      object
# Gross claims incurred (£m).2                      object
# Gross claims incurred (£m).3                      object
# Gross claims incurred (£m).4                      object
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m)      object
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).1    object
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).2    object
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).3    object
# Gross BEL (inc. TPs as whole, pre-TMTP) (£m).4    object
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m)      object
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).1    object
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).2    object
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).3    object
# Net BEL (inc. TPs as a whole, pre-TMTP) (£m).4    object
# ...

# %%
# There are 326 rows and 6 columns in Dataset 1 and 326 rows and 5 columns in Dataset.
# The first two rows of Dataset 1 and Dataset 2 being header and the third row being the first row of data.
# The first column of Dataset 1 and Dataset 2 being the index column with 'Firm_ID'.

# As there are 2 headers rows for Dataset 1, create a new header from the first two rows for clarity
# Create a new header from the first two rows
new_header = [f"{df.iloc[0, i]}_{df.columns[i]}" if not pd.isna(df.iloc[0, i]) else df.columns[i] for i in range(df.shape[1])]

# Remove any generated trailing numbers (e.g., '.1', '.2', etc.) from the header
import re
new_header = [re.sub(r'\.\d+$', '', header) for header in new_header]

# Assign the new header to the DataFrame and drop the first two rows
df.columns = new_header
df = df.drop(df.index[0])

# Reset the index
df.reset_index(drop=True, inplace=True)

# Set to display all columns
pd.set_option('display.max_columns', None)

# reinspect the dataframe
df.head(5)
# Out:
#   Unnamed: 0 2016YE_NWP (£m)  2017YE_NWP (£m)  2018YE_NWP (£m)   \
# 0     Firm 1    -13779.815629                0                0
# 1     Firm 2        28.178059        26.865049        25.064438
# 2     Firm 3                0        75.609681        70.578732
# 3     Firm 4     22344.199923     23963.910709     25760.390158
# 4     Firm 5        68.200993        51.663132        44.010833
#
#   2019YE_NWP (£m)  2020YE_NWP (£m)  2016YE_SCR (£m) 2017YE_SCR (£m)  \
# 0                0                0     1085.360139             0.0
# 1        23.226445        21.718558       10.190314       10.113572
# 2        78.432782         85.73583      322.955115      363.782327
# 3     25512.748836     24996.021042      16573.6448      16332.7488
# 4        42.008556        81.273653       52.824396       38.053768
#
#   2018YE_SCR (£m) 2019YE_SCR (£m) 2020YE_SCR (£m) 2016YE_EoF for SCR (£m)  \
# 0               0               0               0             2230.076702
# ...

# %%
# Similarly, there are 2 headers rows for Dataset 2, create a new header from the first two rows
# Create a new header from the first two rows for clarity
new_header2 = [f"{df_1.iloc[0, i]}_{df_1.columns[i]}" if not pd.isna(df_1.iloc[0, i]) else df_1.columns[i] for i in range(df_1.shape[1])]

# Remove any trailing numbers (e.g., '.1', '.2', etc.) from the header
import re
new_header2 = [re.sub(r'\.\d+$', '', header) for header in new_header2]

# Assign the new header to the DataFrame and drop the first two rows
df_1.columns = new_header2
df_1 = df_1.drop(df.index[0])

# Reset the index
df_1.reset_index(drop=True, inplace=True)

# Set to display all columns
pd.set_option('display.max_columns', None)

# reinspect the dataframe
df_1.head(5)
# Out:
#   Unnamed: 0 2016YE_Gross claims incurred (£m)  \
# 0     Firm 1                                 0
# 1     Firm 2                         39.241067
# 2     Firm 3                                 0
# 3     Firm 4                         17.125976
# 4     Firm 5                         30.485185
#
#   2017YE_Gross claims incurred (£m) 2018YE_Gross claims incurred (£m)  \
# 0                          0.046674                                 0
# 1                         35.948249                         29.002244
# 2                                 0                                 0
# 3                         75.535951                        119.426995
# 4                        247.872969                         449.87474
#
#   2019YE_Gross claims incurred (£m) 2020YE_Gross claims incurred (£m)  \
# 0                                 0                                 0
# 1                                 0                                 0
# ...

# %%
# for the first dataset, rename the first column "Unnamed: 0" to "Firms_ID".
df = df.rename(columns={'Unnamed: 0':'Firms_ID'})

# for the second dataset, rename the first column "Unnamed: 0" to "Firms_ID".
df_1 = df_1.rename(columns={'Unnamed: 0':'Firms_ID'})

print(df.columns)
print(df_1.columns)
# Out:
# Index(['Firms_ID', '2016YE_NWP (£m) ', '2017YE_NWP (£m) ', '2018YE_NWP (£m) ',
#        '2019YE_NWP (£m) ', '2020YE_NWP (£m) ', '2016YE_SCR (£m)',
#        '2017YE_SCR (£m)', '2018YE_SCR (£m)', '2019YE_SCR (£m)',
#        '2020YE_SCR (£m)', '2016YE_EoF for SCR (£m)', '2017YE_EoF for SCR (£m)',
#        '2018YE_EoF for SCR (£m)', '2019YE_EoF for SCR (£m)',
#        '2020YE_EoF for SCR (£m)', '2016YE_SCR coverage ratio',
#        '2017YE_SCR coverage ratio', '2018YE_SCR coverage ratio',
#        '2019YE_SCR coverage ratio', '2020YE_SCR coverage ratio',
#        '2016YE_GWP (£m)', '2017YE_GWP (£m)', '2018YE_GWP (£m)',
#        '2019YE_GWP (£m)', '2020YE_GWP (£m)', '2016YE_Total assets (£m)',
#        '2017YE_Total assets (£m)', '2018YE_Total assets (£m)',
#        '2019YE_Total assets (£m)', '2020YE_Total assets (£m)',
#        '2016YE_Total liabilities (£m)', '2017YE_Total liabilities (£m)',
#        '2018YE_Total liabilities (£m)', '2019YE_Total liabilities (£m)',
# ...

# %%
# as Dataset 1 and Dataset 2 have the same column index which is the 'Firm_ID', we can merge them together
df_c = pd.merge(df, df_1, on = "Firms_ID")
df_c.head(5)
# Out:
#   Firms_ID 2016YE_NWP (£m)  2017YE_NWP (£m)  2018YE_NWP (£m)   \
# 0   Firm 1    -13779.815629                0                0
# 1   Firm 2        28.178059        26.865049        25.064438
# 2   Firm 3                0        75.609681        70.578732
# 3   Firm 4     22344.199923     23963.910709     25760.390158
# 4   Firm 5        68.200993        51.663132        44.010833
#
#   2019YE_NWP (£m)  2020YE_NWP (£m)  2016YE_SCR (£m) 2017YE_SCR (£m)  \
# 0                0                0     1085.360139             0.0
# 1        23.226445        21.718558       10.190314       10.113572
# 2        78.432782         85.73583      322.955115      363.782327
# 3     25512.748836     24996.021042      16573.6448      16332.7488
# 4        42.008556        81.273653       52.824396       38.053768
#
#   2018YE_SCR (£m) 2019YE_SCR (£m) 2020YE_SCR (£m) 2016YE_EoF for SCR (£m)  \
# 0               0               0               0             2230.076702
# ...

# %%
# converting the data type for data columns (except 'Firm_ID') in the merged dataset to float
cols = df_c.columns.drop('Firms_ID')
df_c[cols] = df_c[cols].astype(float)

# %%
df_c[cols]
# Out:
#      2016YE_NWP (£m)   2017YE_NWP (£m)   2018YE_NWP (£m)   2019YE_NWP (£m)   \
# 0       -13779.815629          0.000000          0.000000          0.000000
# 1           28.178059         26.865049         25.064438         23.226445
# 2            0.000000         75.609681         70.578732         78.432782
# 3        22344.199923      23963.910709      25760.390158      25512.748836
# 4           68.200993         51.663132         44.010833         42.008556
# ..                ...               ...               ...               ...
# 320          0.000000          0.000000         -1.011367         -6.599067
# 321       2092.156137       2084.124818       2022.212247       2103.048716
# 322          0.000000          0.000000          0.000000          0.000000
# 323         23.415380         22.650321         24.268465         25.811984
# 324        240.999886        252.698937        332.521848        294.886332
#
# ...

# %%
# set 'Firms_ID' as index - this is to accuracy and easier to plot the graph
df = df.set_index('Firms_ID')
df_1 = df_1.set_index('Firms_ID')
df_c = df_c.set_index('Firms_ID')

# rewrite 'Firms_ID' remove space, and replace with underscore
df.index = df.index.str.replace(' ', '_')
df_1.index = df_1.index.str.replace(' ', '_')
df_c.index = df_c.index.str.replace(' ', '_')

# rewrite so that include firms_id as index

# %% [markdown]
# ## Firms Size Analysis

# %%
# combine total asset columns to a single dataframe
ta = df_c[['2016YE_Total assets (£m)','2017YE_Total assets (£m)', '2018YE_Total assets (£m)', '2019YE_Total assets (£m)', '2020YE_Total assets (£m)']]

# combine gross written premium columns to a single dataframe
tgwp = df_c[['2016YE_GWP (£m)','2017YE_GWP (£m)', '2018YE_GWP (£m)', '2019YE_GWP (£m)', '2020YE_GWP (£m)']]

# combine net written premium columns to a single dataframe
tnwp = df_c[['2016YE_NWP (£m) ','2017YE_NWP (£m) ', '2018YE_NWP (£m) ', '2019YE_NWP (£m) ', '2020YE_NWP (£m) ']]

# %%
# Calculate total sum of each metrics to 2 decimal places and show general number with thousand separator
print(ta.sum().map('{:,.2f}'.format))
print(ta.sum().pct_change().map('{:.2%}'.format))
print(tgwp.sum().map('{:,.2f}'.format))
print(tgwp.sum().pct_change().map('{:.2%}'.format))
print(tnwp.sum().map('{:,.2f}'.format))
print(tnwp.sum().pct_change().map('{:.2%}'.format))
# Out:
# 2016YE_Total assets (£m)    2,302,481.25
# 2017YE_Total assets (£m)    2,355,996.35
# 2018YE_Total assets (£m)    2,252,268.47
# 2019YE_Total assets (£m)    2,473,086.61
# 2020YE_Total assets (£m)    2,458,373.15
# dtype: object
# 2016YE_Total assets (£m)      nan%
# 2017YE_Total assets (£m)     2.32%
# 2018YE_Total assets (£m)    -4.40%
# 2019YE_Total assets (£m)     9.80%
# 2020YE_Total assets (£m)    -0.59%
# dtype: object
# 2016YE_GWP (£m)    273,691.18
# 2017YE_GWP (£m)    295,676.66
# 2018YE_GWP (£m)    340,196.14
# 2019YE_GWP (£m)    316,059.10
# 2020YE_GWP (£m)    269,890.43
# dtype: object
# 2016YE_GWP (£m)       nan%
# 2017YE_GWP (£m)      8.03%
# 2018YE_GWP (£m)     15.06%
# 2019YE_GWP (£m)     -7.10%
# 2020YE_GWP (£m)    -14.61%
# dtype: object
# 2016YE_NWP (£m)     207,222.22
# 2017YE_NWP (£m)     259,873.53
# 2018YE_NWP (£m)     274,310.07
# 2019YE_NWP (£m)     254,271.27
# 2020YE_NWP (£m)     213,963.82
# dtype: object
# 2016YE_NWP (£m)        nan%
# ...

# %%
# check for descriptive statistics for each
print(ta.describe())
print(tgwp.describe())
print(tnwp.describe())
# Out:
#        2016YE_Total assets (£m)  2017YE_Total assets (£m)  \
# count                325.000000                325.000000
# mean                7084.557700               7249.219525
# std                26542.111520              30607.376781
# min                    0.000000                -54.526842
# 25%                   26.418659                 19.791889
# 50%                  157.456339                137.837056
# 75%                 1199.598522               1091.167855
# max               284329.904525             298172.843043
#
#        2018YE_Total assets (£m)  2019YE_Total assets (£m)  \
# count                325.000000                325.000000
# mean                6930.056846               7609.497261
# std                28996.531235              32341.403195
# min                 -161.954321               -217.429787
# 25%                   17.780399                  8.467582
# 50%                  120.712705                104.938152
# ...

# %%
# create a table for total asset, sorted by 2020YE_Total assets (£m) in descending order
ta = ta.sort_values(by = '2020YE_Total assets (£m)', ascending = False)
ta.head(10).style.set_sticky(axis="index").background_gradient(cmap='Blues').format("{:,.2f}") #format for 2 decimal places with thousand separator
# Out:
# <style type="text/css">
# #T_f237f thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_f237f tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_f237f_row0_col0, #T_f237f_row0_col1, #T_f237f_row0_col2, #T_f237f_row0_col3, #T_f237f_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f237f_row1_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_f237f_row1_col1, #T_f237f_row1_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_f237f_row1_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_f237f_row1_col4 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_f237f_row2_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_f237f_row2_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_f237f_row2_col2 {
#   background-color: #5aa2cf;
# ...

# %%
# create a table for gross written premium, sorted by 2020YE_GWP (£m) in descending order
tgwp = tgwp.sort_values(by = '2020YE_GWP (£m)', ascending = False)
tgwp.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}") #format for 2 decimal places with thousand separator
# Out:
# <style type="text/css">
# #T_8d0c8_row0_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_8d0c8_row0_col1, #T_8d0c8_row0_col2, #T_8d0c8_row0_col3, #T_8d0c8_row0_col4, #T_8d0c8_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d0c8_row1_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_8d0c8_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_8d0c8_row1_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_8d0c8_row1_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_8d0c8_row1_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_8d0c8_row2_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_8d0c8_row2_col1, #T_8d0c8_row8_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_8d0c8_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8d0c8_row2_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# ...

# %%
# create a table for net written premium, sorted by 2020YE_NWP (£m) in descending order
tnwp = tnwp.sort_values(by = '2020YE_NWP (£m) ', ascending = False)
tnwp.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}") #format for 2 decimal places with thousand separator
# Out:
# <style type="text/css">
# #T_5914e_row0_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_5914e_row0_col1, #T_5914e_row0_col2, #T_5914e_row0_col3, #T_5914e_row0_col4, #T_5914e_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5914e_row1_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_5914e_row1_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_5914e_row1_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_5914e_row1_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_5914e_row1_col4 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_5914e_row2_col0, #T_5914e_row7_col0, #T_5914e_row8_col1, #T_5914e_row8_col2, #T_5914e_row8_col3, #T_5914e_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5914e_row2_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_5914e_row2_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# ...

# %%
# vizualize the total asset data using horizontal bar chart, display top 10 firms with highest total asset for year 2020
ta_2020 = ta['2020YE_Total assets (£m)'].sort_values(ascending=False).head(10)

# highest horizontal bar chart at the top
ax = ta_2020.plot(kind='barh', figsize=(10, 6), zorder=2, width=0.85)
plt.xlabel('Total Assets (£m)')
plt.ylabel('Firms_ID')
plt.title('Top 10 Firms with Highest Total Assets in 2020')
plt.tight_layout()
ax.invert_yaxis()
ax.bar_label(ax.containers[0], label_type='center', color='white', fontsize=10, fmt='{:,.2f}')
plt.show()

# %%
# vizualize the gross written premium data using horizontal bar chart, display top 10 firms with highest gross written premium for year 2020
tgwp_2020 = tgwp['2020YE_GWP (£m)'].sort_values(ascending=False).head(10)

# highest horizontal bar chart at the top
ax = tgwp_2020.plot(kind='barh', figsize=(10, 6), zorder=2, width=0.85)
plt.xlabel('Gross Written Premium (£m)')
plt.ylabel('Firms_ID')
plt.title('Top 10 Firms with Highest Gross Written Premium in 2020')
plt.tight_layout()
ax.invert_yaxis()
ax.bar_label(ax.containers[0], label_type='center', color='white', fontsize=10, fmt='{:,.2f}')
plt.show()

# %%
# vizualize the net written premium data using horizontal bar chart, display top 10 firms with highest net written premium for year 2020
tnwp_2020 = tnwp['2020YE_NWP (£m) '].sort_values(ascending=False).head(10)

# highest horizontal bar chart at the top
ax = tnwp_2020.plot(kind='barh', figsize=(10, 6), zorder=2, width=0.85)
plt.xlabel('Net Written Premium (£m)')
plt.ylabel('Firms_ID')
plt.title('Top 10 Firms with Highest Net Written Premium in 2020')
plt.tight_layout()
ax.invert_yaxis()
ax.bar_label(ax.containers[0], label_type='center', color='white', fontsize=10, fmt='{:,.2f}')
plt.show()

# %%
# put all ta, tgwp and tnwp horizontal bar into one plot, inver
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
ta_2020.plot(kind='barh', ax=axes[0], title='Total Assets (£m)')
tgwp_2020.plot(kind='barh', ax=axes[1], title='Gross Written Premium (£m)')
tnwp_2020.plot(kind='barh', ax=axes[2], title='Net Written Premium (£m)')
plt.tight_layout()
#invert all y axis for all plots
for ax in axes:
    ax.invert_yaxis()
    ax.set_xlabel('Firms_ID')
    ax.set_ylabel('Amount (£m)')
# add label to all bar, with thousand separator and 2 decimal places, inside the bar
for ax in axes:
    ax.bar_label(ax.containers[0], label_type='center', color='white', fontsize=10, fmt='{:,.2f}')
plt.show()

# %%
# create a line chart for tnwp(10)
tnwp_10 = tnwp.head(10)
tnwp_10 = tnwp_10.T
tnwp_10.plot(kind='line', figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Net Written Premium (£m)')
plt.title('Net Written Premium for Top 10 Firms')
plt.tight_layout()
plt.show()

# %%
#modify each column name to remove the 'YE' and 'Total assets (£m)', 'GWP (£m)', 'NWP (£m)' to make it shorter
#this is to make the graph more readable
#rename the column name without chaning the original dataframe
ta = ta.rename(columns={'2016YE_Total assets (£m)':'2016', '2017YE_Total assets (£m)':'2017', '2018YE_Total assets (£m)':'2018', '2019YE_Total assets (£m)':'2019', '2020YE_Total assets (£m)':'2020'})
tgwp = tgwp.rename(columns={'2016YE_GWP (£m)':'2016', '2017YE_GWP (£m)':'2017', '2018YE_GWP (£m)':'2018', '2019YE_GWP (£m)':'2019', '2020YE_GWP (£m)':'2020'})
tnwp = tnwp.rename(columns={'2016YE_NWP (£m) ':'2016', '2017YE_NWP (£m) ':'2017', '2018YE_NWP (£m) ':'2018', '2019YE_NWP (£m) ':'2019', '2020YE_NWP (£m) ':'2020'})

# create a line chart for tnwp(10), ta(10) and tgwp(10) in one plot
tnwp_10 = tnwp.head(10)
ta_10 = ta.head(10)
tgwp_10 = tgwp.head(10)
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
tnwp_10 = tnwp_10.T
ta_10 = ta_10.T
tgwp_10 = tgwp_10.T
ta_10.plot(kind='line', ax=axes[0], title='Total Assets (£m)', legend=False)
tgwp_10.plot(kind='line', ax=axes[1], title='Gross Written Premium (£m)', legend=False)
tnwp_10.plot(kind='line', ax=axes[2], title='Net Written Premium (£m)', legend=False)
# add legend to only one plot, with padding and not overlapping with the plot
plt.tight_layout()
#invert all y axis for all plots
for ax in axes:
    ax.set_xlabel('Year')
    ax.set_ylabel('Amount (£m)')
    axes[2].legend(loc='upper center', bbox_to_anchor=(1.2, 0.8), ncol=1)
plt.show()

# %%
# calculate firms concentration by total asset, for every period
for col in ta.columns:
    total = ta[col].sum()
    ta[col + '(%)'] = round((ta[col] / total) * 100, 2)

ta_sort = ta.iloc[:,5:10].sort_values(by=['2020(%)'], ascending=False)
ta_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_1f268_row0_col0, #T_1f268_row0_col1, #T_1f268_row0_col2, #T_1f268_row0_col3, #T_1f268_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1f268_row1_col0, #T_1f268_row3_col4 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_1f268_row1_col1, #T_1f268_row1_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_1f268_row1_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_1f268_row1_col4 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_1f268_row2_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_1f268_row2_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_1f268_row2_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_1f268_row2_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_1f268_row2_col4 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_1f268_row3_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# ...

# %%
# calculate firms concentration by gross written premium, for every period
for col in tgwp.columns:
    total = tgwp[col].sum()
    tgwp[col + '(%)'] = round((tgwp[col] / total) * 100, 2)


tgwp_sort = tgwp.iloc[:,5:10].sort_values(by=['2020(%)'], ascending=False)
tgwp_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_8d370_row0_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_8d370_row0_col1, #T_8d370_row0_col2, #T_8d370_row0_col3, #T_8d370_row0_col4, #T_8d370_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d370_row1_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_8d370_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_8d370_row1_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_8d370_row1_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_8d370_row1_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_8d370_row2_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_8d370_row2_col1, #T_8d370_row8_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_8d370_row2_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8d370_row2_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# ...

# %%
# calculate firms concentration by net written premium, for every period
for col in tnwp.columns:
    total = tnwp[col].sum()
    tnwp[col + '(%)'] = round((tnwp[col] / total) * 100, 2)


tnwp_sort = tnwp.iloc[:,5:10].sort_values(by=['2020(%)'], ascending=False)
tnwp_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_adb5a_row0_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_adb5a_row0_col1, #T_adb5a_row0_col2, #T_adb5a_row0_col3, #T_adb5a_row0_col4, #T_adb5a_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_adb5a_row1_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_adb5a_row1_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_adb5a_row1_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_adb5a_row1_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_adb5a_row1_col4 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_adb5a_row2_col0, #T_adb5a_row7_col0, #T_adb5a_row8_col1, #T_adb5a_row8_col2, #T_adb5a_row8_col3, #T_adb5a_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_adb5a_row2_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_adb5a_row2_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# ...

# %%
tnwp_tgwp_ratio = (tnwp.iloc[:,0:5] / tgwp.iloc[:,0:5]).sort_values(by=['2020'], ascending=False)
tnwp_tgwp_ratio.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3823: RuntimeWarning: invalid value encountered in scalar multiply
#   norm = _matplotlib.colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# #T_f1524_row0_col0, #T_f1524_row0_col1, #T_f1524_row0_col2, #T_f1524_row0_col3, #T_f1524_row0_col4, #T_f1524_row1_col4, #T_f1524_row2_col4, #T_f1524_row3_col4, #T_f1524_row4_col4, #T_f1524_row5_col4, #T_f1524_row6_col4, #T_f1524_row7_col4, #T_f1524_row8_col4, #T_f1524_row9_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f1524_row1_col0, #T_f1524_row1_col1, #T_f1524_row2_col2, #T_f1524_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f1524_row1_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_f1524_row1_col3, #T_f1524_row3_col1, #T_f1524_row5_col2, #T_f1524_row6_col0, #T_f1524_row7_col0, #T_f1524_row8_col0, #T_f1524_row9_col0 {
# ...

# %% [markdown]
# ## Changing Business Profile

# %%
# selecting eligible own funds
teof = df_c[['2016YE_EoF for SCR (£m)','2017YE_EoF for SCR (£m)', '2018YE_EoF for SCR (£m)', '2019YE_EoF for SCR (£m)', '2020YE_EoF for SCR (£m)']]

# selecting SCR
tscr = df_c[['2016YE_SCR (£m)','2017YE_SCR (£m)', '2018YE_SCR (£m)', '2019YE_SCR (£m)', '2020YE_SCR (£m)']]

# selecting SCR coverage ratio
tscrcr = df_c[['2016YE_SCR coverage ratio','2017YE_SCR coverage ratio', '2018YE_SCR coverage ratio', '2019YE_SCR coverage ratio', '2020YE_SCR coverage ratio']]

# selecting gross claims incurred 
tgci = df_c[['2016YE_Gross claims incurred (£m)','2017YE_Gross claims incurred (£m)', '2018YE_Gross claims incurred (£m)', '2019YE_Gross claims incurred (£m)', '2020YE_Gross claims incurred (£m)']]

# selecting gross BEL
tgbel = df_c[['2016YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)','2017YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)', '2018YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)', '2019YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)', '2020YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)']]

# selecting net BEl
tnbel = df_c[['2016YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)','2017YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)', '2018YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)', '2019YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)', '2020YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)']]

# selecting pure net claims ratio
tpncr = df_c[['2016YE_Pure net claims ratio','2017YE_Pure net claims ratio', '2018YE_Pure net claims ratio', '2019YE_Pure net claims ratio', '2020YE_Pure net claims ratio']]

df_c['2016YE_Net expense ratio']
# selecting net expense ratio
tnexr = df_c[['2016YE_Net expense ratio','2017YE_Net expense ratio', '2018YE_Net expense ratio', '2019YE_Net expense ratio', '2020YE_Net expense ratio']]

# selecting net combined ratio
tncri = df_c[['2016YE_Net combined ratio','2017YE_Net combined ratio', '2018YE_Net combined ratio', '2019YE_Net combined ratio', '2020YE_Net combined ratio']]

# selecting pure gross claims ratio
tpgcr = df_c[['2016YE_Pure gross claims ratio','2017YE_Pure gross claims ratio', '2018YE_Pure gross claims ratio', '2019YE_Pure gross claims ratio', '2020YE_Pure gross claims ratio']]

# selecting gross expense ratio
tgexr = df_c[['2016YE_Gross expense ratio','2017YE_Gross expense ratio', '2018YE_Gross expense ratio', '2019YE_Gross expense ratio', '2020YE_Gross expense ratio']]

# selecting gross combined ratio
tgcri = df_c[['2016YE_Gross combined ratio','2017YE_Gross combined ratio', '2018YE_Gross combined ratio', '2019YE_Gross combined ratio', '2020YE_Gross combined ratio']]

#rename each column
teof = teof.rename(columns={'2016YE_EoF for SCR (£m)':'2016', '2017YE_EoF for SCR (£m)':'2017', '2018YE_EoF for SCR (£m)':'2018', '2019YE_EoF for SCR (£m)':'2019', '2020YE_EoF for SCR (£m)':'2020'})
tscr = tscr.rename(columns={'2016YE_SCR (£m)':'2016', '2017YE_SCR (£m)':'2017', '2018YE_SCR (£m)':'2018', '2019YE_SCR (£m)':'2019', '2020YE_SCR (£m)':'2020'})
tscrcr = tscrcr.rename(columns={'2016YE_SCR coverage ratio':'2016', '2017YE_SCR coverage ratio':'2017', '2018YE_SCR coverage ratio':'2018', '2019YE_SCR coverage ratio':'2019', '2020YE_SCR coverage ratio':'2020'})
tgci = tgci.rename(columns={'2016YE_Gross claims incurred (£m)':'2016', '2017YE_Gross claims incurred (£m)':'2017', '2018YE_Gross claims incurred (£m)':'2018', '2019YE_Gross claims incurred (£m)':'2019', '2020YE_Gross claims incurred (£m)':'2020'})
tgbel = tgbel.rename(columns={'2016YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)':'2016', '2017YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)':'2017', '2018YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)':'2018', '2019YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)':'2019', '2020YE_Gross BEL (inc. TPs as whole, pre-TMTP) (£m)':'2020'})
tnbel = tnbel.rename(columns={'2016YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)':'2016', '2017YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)':'2017', '2018YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)':'2018', '2019YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)':'2019', '2020YE_Net BEL (inc. TPs as a whole, pre-TMTP) (£m)':'2020'})
tpncr = tpncr.rename(columns={'2016YE_Pure net claims ratio':'2016', '2017YE_Pure net claims ratio':'2017', '2018YE_Pure net claims ratio':'2018', '2019YE_Pure net claims ratio':'2019', '2020YE_Pure net claims ratio':'2020'})
tnexr = tnexr.rename(columns={'2016YE_Net expense ratio':'2016', '2017YE_Net expense ratio':'2017', '2018YE_Net expense ratio':'2018', '2019YE_Net expense ratio':'2019', '2020YE_Net expense ratio':'2020'})
tncri = tncri.rename(columns={'2016YE_Net combined ratio':'2016', '2017YE_Net combined ratio':'2017', '2018YE_Net combined ratio':'2018', '2019YE_Net combined ratio':'2019', '2020YE_Net combined ratio':'2020'})
tpgcr = tpgcr.rename(columns={'2016YE_Pure gross claims ratio':'2016', '2017YE_Pure gross claims ratio':'2017', '2018YE_Pure gross claims ratio':'2018', '2019YE_Pure gross claims ratio':'2019', '2020YE_Pure gross claims ratio':'2020'})
tgexr = tgexr.rename(columns={'2016YE_Gross expense ratio':'2016', '2017YE_Gross expense ratio':'2017', '2018YE_Gross expense ratio':'2018', '2019YE_Gross expense ratio':'2019', '2020YE_Gross expense ratio':'2020'})
tgcri = tgcri.rename(columns={'2016YE_Gross combined ratio':'2016', '2017YE_Gross combined ratio':'2017', '2018YE_Gross combined ratio':'2018', '2019YE_Gross combined ratio':'2019', '2020YE_Gross combined ratio':'2020'})

# %%
# calculate pure gross claims ratio for every period for each firm using boxplot
print(tpgcr.describe())
tpgcr.boxplot(figsize=(10,6))
plt.xlabel('Year')
plt.ylabel('Pure Gross Claims Ratio')
plt.title('Pure Gross Claims Ratio for Each Firm')
plt.tight_layout()
plt.show()

# create a variable outlier dataframe to allow return of the outlier in a dataframe with year column
q1 = tpgcr.quantile(0.25)
q3 = tpgcr.quantile(0.75)
iqr = q3 - q1
tpgcr_outlier = ((tpgcr < (q1 - 1.5 * iqr)) | (tpgcr > (q3 + 1.5 * iqr))).any(axis=1)

# new variable without outliers to improve readability of the boxplot
tpgcr_mod = tpgcr[~((tpgcr < (q1 - 1.5 * iqr)) | (tpgcr > (q3 + 1.5 * iqr))).any(axis=1)]

# create a box plot of tpgcr
# add a reference line of 100% or at 1.0, this ratio should be less than this, if more than 100% means the firm is not profitable.
# if more than 100%, there is sign of risk  mispricing and an incentive to invest in riskier asset to try to make the insurers profitable overall
tpgcr_mod.boxplot(figsize=(10,6))
plt.axhline(y=1.0, color='r', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Pure Gross Claims Ratio')
plt.title('Pure Gross Claims Ratio for Each Firm')
plt.tight_layout()
plt.show()
# Out:
#              2016          2017         2018          2019         2020
# count  325.000000    325.000000   325.000000  3.250000e+02   325.000000
# mean    -0.110588    -72.376536    26.204866  5.872168e+03     9.801827
# std     31.446878   1438.129350   461.725941  1.060098e+05    94.435270
# min   -387.557255 -25876.266020  -160.128397 -2.893406e+03   -21.021266
# 25%      0.000000      0.000000     0.000000  0.000000e+00     0.000000
# 50%      0.162931      0.310568     0.323024  1.962327e-01     0.000000
# 75%      0.578166      0.698855     0.663285  6.300366e-01     0.627148
# max    321.359543    899.702268  8321.272846  1.911108e+06  1165.884916

# %%
# sort the pure gross claims (before cleaning) ratio by 2020 in descending order
tpgcr_sort = tpgcr.sort_values(by=['2020'], ascending=False)
tpgcr_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_433e4_row0_col0, #T_433e4_row0_col2, #T_433e4_row0_col3, #T_433e4_row1_col1, #T_433e4_row5_col4, #T_433e4_row6_col4, #T_433e4_row7_col4, #T_433e4_row8_col4, #T_433e4_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_433e4_row0_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_433e4_row0_col4, #T_433e4_row3_col0, #T_433e4_row3_col1, #T_433e4_row3_col2, #T_433e4_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_433e4_row1_col0, #T_433e4_row2_col0, #T_433e4_row6_col0, #T_433e4_row7_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_433e4_row1_col2 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_433e4_row1_col3, #T_433e4_row6_col3, #T_433e4_row7_col3, #T_433e4_row8_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_433e4_row1_col4 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# ...

# %%
# sort the pure gross claims (after cleaning) ratio by 2020 in descending order
print(tpgcr_mod.describe())
tpgcr_mod_sort = tpgcr_mod.sort_values(by=['2020'], ascending=False)
tpgcr_mod_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")

#to calculate use shape
#tpgcr_mod_sort.shape = 285, 5
# Out:
#              2016        2017        2018        2019        2020
# count  285.000000  285.000000  285.000000  285.000000  285.000000
# mean     0.295359    0.368160    0.342712    0.309643    0.323780
# std      0.326850    0.391340    0.349080    0.341326    0.357707
# min     -0.113431   -0.536276   -0.315361   -0.889447   -0.301601
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.162931    0.305848    0.321162    0.213447    0.183942
# 75%      0.567755    0.685976    0.641764    0.619649    0.622522
# max      1.286180    1.626692    1.652928    1.282594    1.373235
# <style type="text/css">
# #T_2355b_row0_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_2355b_row0_col1, #T_2355b_row4_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_2355b_row0_col2, #T_2355b_row1_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_2355b_row0_col3, #T_2355b_row9_col0 {
#   background-color: #4896c8;
# ...

# %%
# calculate YoY of pure gross claims ratio of tpgcr_mod_sort all years
tpgcr_mod_yoy = tpgcr_mod_sort.pct_change(axis='columns').mul(100).round(2)
tpgcr_mod_yoy.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3819: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3820: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3823: RuntimeWarning: invalid value encountered in scalar multiply
#   norm = _matplotlib.colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# ...

# %%
# create a box plot of net combined ratio for each firm
print(tncri.describe())
tncri.boxplot(figsize=(10, 6))
plt.ylabel('Net Combined Ratio')
plt.title('Net Combined Ratio Boxplot')
plt.show()

# create a variable outlier dataframe to allow return of the outlier in a dataframe with year column
q1 = tncri.quantile(0.25)
q3 = tncri.quantile(0.75)
iqr = q3 - q1
tncri_outlier = ((tncri < (q1 - 1.5 * iqr)) | (tncri > (q3 + 1.5 * iqr))).any(axis=1)

# new variable without outliers to improve readability of the boxplot
tncri_mod = tncri[~((tncri < (q1 - 1.5 * iqr)) | (tncri > (q3 + 1.5 * iqr))).any(axis=1)]

# create a box plot of tncri
# add a reference line of 100% or at 1.0
tncri_mod.boxplot(figsize=(10, 6))
plt.axhline(y=1.0, color='r', linestyle='-')
plt.ylabel('Net Combined Ratio')
plt.title('Net Combined Ratio Boxplot')
plt.tight_layout()
plt.show()
# Out:
#              2016          2017         2018          2019         2020
# count  325.000000    325.000000   325.000000  3.250000e+02   325.000000
# mean     1.349348   -133.048986     5.986255  7.477469e+03     9.853370
# std     15.126252   2560.806827    87.892041  1.347934e+05    95.090048
# min   -124.288370 -46116.696842    -2.013885 -2.516977e+02    -9.490844
# 25%      0.000000      0.000000     0.000000  0.000000e+00     0.000000
# 50%      0.327623      0.732771     0.793606  6.178107e-01     0.227627
# 75%      0.959809      1.041880     1.005938  9.751001e-01     0.988144
# max    198.007110   1738.295847  1578.853894  2.430023e+06  1076.158703

# %%
# sort the net combined ratio (before cleaning - without outlier) ratio by 2020 in descending order
tncri_sort = tncri.sort_values(by=['2020'], ascending=False)
tncri_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_0ba68_row0_col0, #T_0ba68_row0_col2, #T_0ba68_row1_col3, #T_0ba68_row2_col0, #T_0ba68_row2_col2, #T_0ba68_row3_col1, #T_0ba68_row4_col0, #T_0ba68_row4_col2, #T_0ba68_row5_col0, #T_0ba68_row5_col2, #T_0ba68_row5_col4, #T_0ba68_row6_col4, #T_0ba68_row7_col0, #T_0ba68_row7_col4, #T_0ba68_row8_col4, #T_0ba68_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0ba68_row0_col1, #T_0ba68_row2_col1, #T_0ba68_row4_col1, #T_0ba68_row5_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_0ba68_row0_col3, #T_0ba68_row4_col3, #T_0ba68_row8_col3, #T_0ba68_row9_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_0ba68_row0_col4, #T_0ba68_row1_col0, #T_0ba68_row2_col3, #T_0ba68_row3_col2, #T_0ba68_row7_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ba68_row1_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_0ba68_row1_col2, #T_0ba68_row4_col4 {
#   background-color: #f4f9fe;
# ...

# %%
# sort the net combined ratio (after cleaning - without outlier) ratio by 2020 in descending order
print(tncri_mod.describe())
tncri_mod_sort = tncri_mod.sort_values(by=['2020'], ascending=False)
tncri_mod_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
#              2016        2017        2018        2019        2020
# count  288.000000  288.000000  288.000000  288.000000  288.000000
# mean     0.508397    0.585547    0.567773    0.521803    0.516621
# std      0.539851    0.546949    0.545102    0.515412    0.552255
# min     -0.896605    0.000000   -1.113032    0.000000   -0.200397
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.597382    0.811088    0.809756    0.691984    0.345514
# 75%      0.949548    1.029891    0.997362    0.971385    0.979243
# max      2.053673    2.103911    2.470816    2.052330    2.387685
# <style type="text/css">
# #T_1338a_row0_col0, #T_1338a_row7_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_1338a_row0_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_1338a_row0_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_1338a_row0_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# ...

# %%
# calculate YoY of net combined ratio of tncri_mod_sort all years
tncri_mod_yoy = tncri_mod_sort.pct_change(axis='columns').mul(100).round(2)
tncri_mod_yoy.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3819: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3820: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3823: RuntimeWarning: invalid value encountered in scalar multiply
#   norm = _matplotlib.colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# ...

# %%
# create a box plot for solvency coverage ratio for each firm
print(tscrcr.describe())
tscrcr.boxplot(figsize=(10, 6))
plt.ylabel('Solvency Coverage Ratio')
plt.title('Solvency Coverage Ratio Boxplot')
plt.show()

# create a variable outlier dataframe to allow return of the outlier in a dataframe with year column
q1 = tscrcr.quantile(0.25)
q3 = tscrcr.quantile(0.75)
iqr = q3 - q1
tscrcr_outlier = ((tscrcr < (q1 - 1.5 * iqr)) | (tscrcr > (q3 + 1.5 * iqr))).any(axis=1)

# new variable without outliers to improve readability of the boxplot
tscrcr_mod = tscrcr[~((tscrcr < (q1 - 1.5 * iqr)) | (tscrcr > (q3 + 1.5 * iqr))).any(axis=1)]

# create a box plot of tscrcr
# add a reference line of 100% or at 1.0
tscrcr_mod.boxplot(figsize=(10, 6))
plt.axhline(y=1.0, color='r', linestyle='-')
plt.ylabel('Solvency Coverage Ratio')
plt.title('Solvency Coverage Ratio Boxplot')
plt.tight_layout()
plt.show()
# Out:
#                2016          2017          2018           2019           2020
# count  3.250000e+02  3.250000e+02  3.250000e+02     325.000000     325.000000
# mean   1.286947e+04  5.930313e+06  1.246741e+04     533.017116     514.215109
# std    2.319518e+05  6.529400e+07  2.141325e+05    9539.236980    9229.786796
# min   -1.974450e+00 -1.973652e+00 -5.515428e-01      -0.669013      -1.066521
# 25%    1.276845e+00  1.302423e+00  1.268210e+00       1.177754       0.000000
# 50%    1.662747e+00  1.755881e+00  1.693416e+00       1.710544       1.565516
# 75%    2.780175e+00  3.203697e+00  2.795907e+00       2.691263       2.367988
# max    4.181573e+06  9.635840e+08  3.856018e+06  171974.690816  166394.575872

# %%
# sort the solvency coverage ratio (before cleaning - without outlier) ratio by 2020 in descending order
tscrcr_sort = tscrcr.sort_values(by=['2020'], ascending=False)
tscrcr_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# <style type="text/css">
# #T_2375a_row0_col0, #T_2375a_row1_col0, #T_2375a_row1_col1, #T_2375a_row1_col2, #T_2375a_row1_col3, #T_2375a_row1_col4, #T_2375a_row2_col1, #T_2375a_row2_col2, #T_2375a_row2_col3, #T_2375a_row2_col4, #T_2375a_row3_col1, #T_2375a_row3_col2, #T_2375a_row3_col3, #T_2375a_row3_col4, #T_2375a_row4_col1, #T_2375a_row4_col2, #T_2375a_row4_col3, #T_2375a_row4_col4, #T_2375a_row5_col1, #T_2375a_row5_col2, #T_2375a_row5_col3, #T_2375a_row5_col4, #T_2375a_row6_col1, #T_2375a_row6_col2, #T_2375a_row6_col3, #T_2375a_row6_col4, #T_2375a_row7_col1, #T_2375a_row7_col2, #T_2375a_row7_col3, #T_2375a_row7_col4, #T_2375a_row8_col1, #T_2375a_row8_col2, #T_2375a_row8_col3, #T_2375a_row8_col4, #T_2375a_row9_col1, #T_2375a_row9_col2, #T_2375a_row9_col3, #T_2375a_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2375a_row0_col1, #T_2375a_row0_col2, #T_2375a_row0_col3, #T_2375a_row0_col4, #T_2375a_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# ...

# %%
# sort the solvency coverage ratio (after cleaning - without outlier) ratio by 2020 in descending order
print(tscrcr_mod.describe())
tscrcr_mod_sort = tscrcr_mod.sort_values(by=['2020'], ascending=False)
tscrcr_mod_sort.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
#              2016        2017        2018        2019        2020
# count  257.000000  257.000000  257.000000  257.000000  257.000000
# mean     1.670129    1.705842    1.668066    1.594209    1.417733
# std      0.993736    1.041048    1.090796    1.096293    1.123326
# min     -0.699561   -0.579237   -0.551543   -0.669013   -1.066521
# 25%      1.237247    1.254904    1.246388    1.154880    0.000000
# 50%      1.495556    1.516419    1.553863    1.579328    1.497979
# 75%      2.167277    2.180775    2.117042    2.152630    2.057611
# max      4.788990    4.839561    5.060825    4.631008    5.426021
# <style type="text/css">
# #T_339bc_row0_col0, #T_339bc_row4_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_339bc_row0_col1, #T_339bc_row0_col2, #T_339bc_row0_col4, #T_339bc_row4_col3, #T_339bc_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_339bc_row0_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# ...

# %%
# calculate YoY of solvency coverage ratio of tscrcr_mod_sort all years
tscrcr_mod_yoy = tscrcr_mod_sort.pct_change(axis='columns').mul(100).round(2)
tscrcr_mod_yoy.head(10).style.background_gradient(cmap='Blues').format("{:,.2f}")
# Out:
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3819: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3820: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# c:\Users\Syarmine\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3823: RuntimeWarning: invalid value encountered in scalar multiply
#   norm = _matplotlib.colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# ...
